# %%
L = range(10)
#L[::2]
L[::4]
# Out:
# range(0, 10, 4)

# %%
s='abcd'
s[::-1]
# Out:
# 'dcba'

# %%
L[::-1]
# Out:
# range(9, -1, -1)

# %%
import numpy as np

# %%
np.array([0.485, 0.456, 0.406])[::-1]
# Out:
# array([0.406, 0.456, 0.485])

# %%
np.array([0.229, 0.224, 0.225])[::-1]
# Out:
# array([0.225, 0.224, 0.229])

# %%
# https://github.com/wellflat/opencv-samples/blob/master/dnn/onnx/read_onnx.py
# https://docs.python.org/2.3/whatsnew/section-slices.html
# https://gist.github.com/mstfldmr/45d6e47bb661800b982c39d30215bc88

# %%
import cv2 as cv
from matplotlib import pyplot as plt

# %%
img: int = cv.imread("../data/marcel2019.jpg")

# %%
img2 = img[:,:,::-1]
plt.imshow(img)

# %%
img3: int = cv.imread("https://raw.githubusercontent.com/hellonico/opencv4_java_tutorial/master/data/marcel2019.jpg")

# %%
img4 = img[:,:,::-1]
plt.imshow(img4)

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-24a1544ec991> in <module>
#       1 import numpy as np
#       2 import argparse
# ----> 3 import imutils
#       4 import sys
#       5 import cv2
#
# ModuleNotFoundError: No module named 'imutils'
